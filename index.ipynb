# %% [markdown]
# #
#
# # 숙제 3
#
# 이름: \[아무개\] 학번: \[나의 학번\]
#
# 이 숙제의 상세 분석 결과는 아래 링크에서 확인하실 수 있습니다.
#
# - [분석 리포트 (HTML)](./hw03.html)
# - [주피터 노트북
#   (ipynb)](https://mybinder.org/v2/ghcr/donghyunlee0306/my-r-env/latest?filepath=hw03.ipynb)
